# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolo11n-cls.pt")  # load a pretrained model (recommended for training)

# Train the model
results = model.train(data="classification_dataset", epochs=35, imgsz=640, patience = 5)
# Out:
# New https://pypi.org/project/ultralytics/8.3.80 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.49  Python-3.11.9 torch-2.5.1+cpu CPU (AMD Ryzen 5 2600 Six-Core Processor)
# ...
