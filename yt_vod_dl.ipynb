# %% [markdown]
# Download VODS for data annotation / generation

# %%
# Playlist for VCT AM Kickoff 2025
# https://www.youtube.com/playlist?list=PLmtbaq-0uOkdYHQoYfxpRXLCRY6JoE6t9

# %% [markdown]
# Import Packages

# %%
import yt_dlp
import os

# %% [markdown]
# Download the desired VODS
#
# Saved to "val_vision\VODS"

# %%
# Ensure the save folder exists
save_folder = "VODS"
os.makedirs(save_folder, exist_ok=True)

# Your VOD URL
VOD_URL = "https://www.youtube.com/watch?v=4SfNoH2cnOc"
# Download 720p full video
ydl_opts = {
    "format": "bestvideo[height=720]",
    "outtmpl": f"{save_folder}/%(title)s.%(ext)s",
}

with yt_dlp.YoutubeDL(ydl_opts) as ydl:
    ydl.download([VOD_URL])
# Out:
# [youtube] Extracting URL: https://www.youtube.com/watch?v=4SfNoH2cnOc
# [youtube] 4SfNoH2cnOc: Downloading webpage
# [youtube] 4SfNoH2cnOc: Downloading tv client config
# [youtube] 4SfNoH2cnOc: Downloading player c8dbda2a
# [youtube] 4SfNoH2cnOc: Downloading tv player API JSON
# [youtube] 4SfNoH2cnOc: Downloading ios player API JSON
# [youtube] 4SfNoH2cnOc: Downloading m3u8 information
# [info] 4SfNoH2cnOc: Downloading 1 format(s): 247
# [download] Destination: VODS\TE vs. T1 - VALORANT Masters Bangkok - Swiss Stage - Map 02.webm
# [download] 100% of  390.77MiB in 00:00:12 at 30.81MiB/s
